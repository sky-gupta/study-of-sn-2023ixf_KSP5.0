# %%
## Import necessary modules 

from astropy.io import fits
from astropy.wcs import WCS
from astropy.stats import sigma_clipped_stats
import glob
import os
import subprocess
import warnings
import numpy as np
import matplotlib.pyplot as plt
import photutils
import pyregion

# You can ignore any warnings that appear below, but if any modules can't be imported you need to install them

# %%
## Define data directories

curpath = os.path.abspath('/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband')                   # top level directory
dataFolder = os.path.join(curpath, 'g_band_data')        # data directory
biasFolder = os.path.join(dataFolder, 'bias')     # bias frames subdirectory
flatFolder = os.path.join(dataFolder, 'flat')     # flat fields subdirectory
sciFolder = os.path.join(dataFolder, 'data')   # science data subdirectory
procFolder = os.path.join(curpath, 'processing')  # processing directory
if not os.path.isdir(procFolder): 
    os.mkdir(procFolder)
else:
    for f in os.listdir(procFolder):
        try:
            os.remove(os.path.join(procFolder,f)) # clear the processing folder from previous iterations
        except:
            print('Could not remove',f)

# %%
os.chdir(sciFolder)
fileList = sorted(glob.glob('*.fits'))
os.chdir(curpath)
biasList = sorted(glob.glob(os.path.join(biasFolder,'*.fits')))
flatList = sorted(glob.glob(os.path.join(flatFolder,'*.fits')))
sciList = [os.path.join(sciFolder, file) for file in fileList]
procList = [os.path.join(procFolder, file).replace('.fits','.proc.fits') for file in fileList]
print('Found',len(biasList),'bias files; ',len(flatList),'flat files; ',len(sciList),'science files')
# Out:
# Found 14 bias files;  8 flat files;  30 science files

# %%
warnings.filterwarnings("ignore")

# %%
## Open an example FITS file

exampleFile = sciList[0]         # The first science image
HDUList = fits.open(exampleFile) # Open the file
HDUList.info()                   # Print some information about the FITS file structure.  
## Print some header properties

header = HDUList[0].header # Get the header out of the HDU list.
print(repr(header[0:13]))  # Print the first 14 lines of the header (in raw format).
print(repr(header[24:34])) # Print some additional lines
print(repr(header[48:52])) 
print(repr(header[67:71])) 
print(repr(header[129:135])) 
print()
print('The object is:', header['OBJECT'])   # Print the name of the object being observed
# print('The filters are:', header['ACAMFILT']) # Print the names of the optical filters in the light path.
print('The exposure time is:', header['EXPTIME'])  # Print the exposure time
# Out:
# Filename: /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230520151900-863-RA.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     133   (4096, 4108)   int16 (rescales to uint16)
# SIMPLE  =                    T / conform to FITS standard
# BITPIX  =                   16 / unsigned short data
# NAXIS   =                    2 / number of axes
# NAXIS1  =                 4096 / length of data axis
# NAXIS2  =                 4108 / length of data axis
# EXTEND  =                    T / this is FITS with extensions
# HISTORY Created with RTS2 version 0.9.5 build on May 12 2020 19:07:30.
# CTIME   =           1684595940 / exposure start (seconds since 1.1.1970)
# USEC    =               863089 / exposure start micro seconds
# JD      =     2460085.13819481 / Modified Julian Date
# DATE-OBS= '2023-05-20T15:19:00.863' / start of exposure
# EXPOSURE=                  60. / exposure length in seconds
# EXPTIME =                  60. / exposure length in seconds
# OBJECT  = 'SN2023ixf'          / target object name
# SLITPOSX=                  -1. / [pixels] slit position along dithering axis
# SLITPOSY=                  -1. / [pixels] slit position along dithering axis
# BINNING = '1x1     '           / [pixelX x pixelY] chip binning
# BINX    =                    1 / [pixels] binning along X axis
# BINY    =                    1 / [pixels] binning along X axis
# CCD_TEMP=                 -41. / CCD temperature
# COOLING =                    T / camera cooling start/stop
# CCD_SET =                 -40. / CCD set temperature
# SHUTTER =                    0 / shutter state (0 - opened, 1 - closed)
# EMON    =                    F / Electron Multiplying status
# ADCHANEL= '18-bit  '           / Used andor AD Channel
# OUTAMP  = 'EMCCD   '           / [bit] Output amplifier
# HSPEED  =         -9.11912E-36 / [MHz] Horizontal shift speed (string)
# OEPOCH  =                2000. / epoch (2000,..)
# PMRA    =                   0. / proper motion/year RA
# PMDEC   =                   0. / proper motion/year DEC
# OFFSRA  =                   0. / object offset RA
# RAIN    = 'Raining '
# TILE_ID =                    0
# CHECKSUM= '6Qc87Pb76Pb76Pb7'   / HDU checksum updated 2023-05-20T15:27:10
# DATASUM = '763235834'          / data unit checksum updated 2023-05-20T15:27:10
#
# The object is: SN2023ixf
# The exposure time is: 60.0

# %%
# Function to find the corresponding flat frame for a given date
default_master_flat_path = os.path.join(flatFolder, 'masterflat_g_.fits')
# default_master_flat = CCDData.read(default_master_flat_path, unit='adu')

def find_flat_for_date(date):
    flat_filename = f'{date}_masterflat_g_.fits'
    flat_path = os.path.join(flatFolder, flat_filename)
    if os.path.exists(flat_path):
        return flat_path
    else:
        return default_master_flat_path

# %%
print(flatList)
import re

def extract_date_from_path(file_path):
    # Extract the file name from the path
    file_name = os.path.basename(file_path)
    
    # Define the regular expression pattern for the date
    date_pattern = r"\d{8}"
    
    # Search for the pattern in the file name
    match = re.search(date_pattern, file_name)
    
    if match:
        return match.group(0)
    else:
        return None
# Out:
# ['/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/20230524_masterflat_g_.fits', '/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/20230525_masterflat_g_.fits', '/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/20230526_masterflat_g_.fits', '/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/20230527_masterflat_g_.fits', '/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/20230603_masterflat_g_.fits', '/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/20230605_masterflat_g_.fits', '/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/20230606_masterflat_g_.fits', '/home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/flat/masterflat_g_.fits']

# %%
## Bias subtract and flat-field all science frames and write out pre-processed files.

numSciFiles = len(sciList)
numBiasFiles = len(biasList)
numFlatFiles = len(flatList)
print('Found %d science files'%numSciFiles)

for i in range(numSciFiles):
    
    # Read in the FITS data.
    HDUList = fits.open(sciList[i])
    primaryHeader = HDUList[0].header
    imageData = HDUList[0].data    
    HDUList.close()
    date=extract_date_from_path(sciList[i])

    bias_image_path = os.path.join(biasFolder, f'{date}_masterbias.fits')
    flat_file_path=find_flat_for_date(date)

    # bias_image=[file for file in biasList if file.startswith(date)]
    # print(bias_image)
    HDUList = fits.open(bias_image_path)
    biasHeader = HDUList[0].header
    masterBias = HDUList[0].data
    HDUList.close()

    HDUList = fits.open(flat_file_path)
    flatHeader = HDUList[0].header
    masterFlatFixed = HDUList[0].data
    HDUList.close()

    # Correct for the bias and flats here
    procData = (imageData - masterBias) / masterFlatFixed

    # Prepare the output FITS structure in simple format
    procHDU = fits.PrimaryHDU(procData)  # Create a new HDU with the processed image data
    procHDU.header = primaryHeader       # Copy over the header from the raw file
    procHDU.header.add_history('Bias corrected and flat-fielded') # Add a note to the header

    # Write the reduced frame to disk
    print(sciList[i],'->',procList[i])
    procHDU.writeto(procList[i], overwrite=True)

    # for j in range(numBiasFiles):
    #     if biasList[j][-24:-16]==sciList[i][-26:-18]:
    #         HDUList = fits.open(biasList[j])
    #         biasHeader = HDUList[0].header
    #         masterBias = HDUList[0].data
    #         HDUList.close()

    #         for k in range(numFlatFiles):
    #             if flatList[k][-27:-19]==sciList[i][-26:-18]:
    #                 HDUList = fits.open(flatList[k])
    #                 flatHeader = HDUList[0].header
    #                 masterFlatFixed = HDUList[0].data
    #                 HDUList.close()
    
    #                 # Correct for the bias and flats here
    #                 procData = (imageData - masterBias) / masterFlatFixed
    
    #                 # Prepare the output FITS structure in simple format
    #                 procHDU = fits.PrimaryHDU(procData)  # Create a new HDU with the processed image data
    #                 procHDU.header = primaryHeader       # Copy over the header from the raw file
    #                 procHDU.header.add_history('Bias corrected and flat-fielded') # Add a note to the header

    #                 # Write the reduced frame to disk
    #                 print(sciList[i],'->',procList[i])
    #                 procHDU.writeto(procList[i], overwrite=True)
# Out:
# Found 30 science files
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230520151900-863-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230520151900-863-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230521151417-752-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230521151417-752-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230521154933-241-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230521154933-241-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230522153045-729-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230522153045-729-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230522154624-727-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230522154624-727-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230523210842-911-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230523210842-911-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230524180955-720-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230524180955-720-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230524182725-957-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230524182725-957-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230525184701-216-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230525184701-216-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230525190514-248-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230525190514-248-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230525195322-030-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230525195322-030-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230526152122-558-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230526152122-558-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230526154421-699-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230526154421-699-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230527144518-321-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230527144518-321-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230527150837-913-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230527150837-913-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230528152042-139-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230528152042-139-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230528153428-317-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230528153428-317-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230530180249-785-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230530180249-785-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230530181621-286-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230530181621-286-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230603150337-154-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230603150337-154-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230603151714-483-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230603151714-483-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230604151623-740-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230604151623-740-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230604153026-612-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230604153026-612-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230605152158-307-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230605152158-307-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230605160040-731-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230605160040-731-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230605163342-989-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230605163342-989-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230605170711-835-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230605170711-835-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230605172106-597-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230605172106-597-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230606145107-018-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230606145107-018-RA.proc.fits
# /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/g_band_data/data/20230606151355-919-RA.fits -> /home/aakashgpt/Desktop/KSP 5.0/TASK3_Imageredgband/processing/20230606151355-919-RA.proc.fits

# %%
# Inspect the processed science files
numProcFiles = len(procList)
plt.figure(figsize=(28,28))
j = 1
for i in range(numProcFiles):
        if os.path.isfile(procList[i]):
            procHDU = fits.open(procList[i])
            procData = procHDU[0].data
            procHDU.close()
            
            mean, median, std = sigma_clipped_stats(procData)
            plt.subplot(7,2,j)
            j = j+1
            plt.imshow(procData, vmin = median - 2*std, vmax = median + 10*std, origin='lower')
            plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 12
#       9 procHDU.close()
#      11 mean, median, std = sigma_clipped_stats(procData)
# ---> 12 plt.subplot(7,2,j)
#      13 j = j+1
#      14 plt.imshow(procData, vmin = median - 2*std, vmax = median + 10*std, origin='lower')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 14, not 15
